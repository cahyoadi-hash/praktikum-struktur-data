# %% [markdown]
# <a href="https://colab.research.google.com/github/cahyoadi-hash/praktikum-struktur-data/blob/main/Modul_9_hashing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("--==Hash tabel sederhana==--")

class SimpleHashTable:
  def __init__(self, size):
    self.size = size
    self.table = [None] * size

  def hash_function(self, key):
    return hash(key) % self.size

  def insert(self, key, value):
    index = self.hash_function(key)
    self.table[index] = value

  def search(self, key):
    index = self.hash_function(key)
    return self.table[index]

#contoh penggunaan
ht = SimpleHashTable(10)
ht.insert("apel", 100)
ht.insert("pisang", 200)

print("Nilai untuk apel : ", ht.search("apel"))
print("Nilai untuk pisang : ", ht.search("pisang"))
print("\n")
print("--- NILAI HASH ASLI ---")
print("Hash asli 'apel'  :", hash("apel"))
print("Hash asli 'pisang':", hash("pisang"))

print("\n--- PROSES MODULUS 10 (hash function) ---")
# 2. Melihat bagaimana angka besar tersebut berubah menjadi indeks 0-9
print(f"Index 'apel'  : {hash('apel')} % 10 = {hash('apel') % 10}")
print(f"Index 'pisang': {hash('pisang')} % 10 = {hash('pisang') % 10}")
print("\n")
print("--- ISI ARRAY SETELAH PROSES HASH FUNCTION ---")
for i in range(ht.size):
    print(f"Ember [{i}]: {ht.table[i]}")
# Out:
# --==Hash tabel sederhana==--
# Nilai untuk apel :  100
# Nilai untuk pisang :  200
#
#
# --- NILAI HASH ASLI ---
# Hash asli 'apel'  : -7398493956312607381
# Hash asli 'pisang': 7923829724054509074
#
# --- PROSES MODULUS 10 (hash function) ---
# Index 'apel'  : -7398493956312607381 % 10 = 9
# Index 'pisang': 7923829724054509074 % 10 = 4
#
#
# --- ISI ARRAY SETELAH PROSES HASH FUNCTION ---
# Ember [0]: None
# Ember [1]: None
# Ember [2]: None
# Ember [3]: None
# Ember [4]: 200
# Ember [5]: None
# Ember [6]: None
# Ember [7]: None
# Ember [8]: None
# Ember [9]: 100

# %%
print("--== Penanganan collision dengan linear probing==--")

class LinearProbingHashTable:
  def __init__(self, size):
    self.size = size
    self.table = [None] * size

  def hash_function(self, key):
    return hash(key) % self.size

  def insert(self, key, value):
    index = self.hash_function(key)
    original_index = index

    while self.table[index] is not None:
      if self.table[index][0] == key:
        break
      index = (index + 1) % self.size
      if index == original_index:
        raise Exception("hash tabel penuh")

    self.table[index] = (key, value)

  def search(self, key):
    index = self.hash_function(key)
    original_index = index
    while self.table[index] is not None:
      if self.table[index][0] == key:
        return self.table[index][1]
      index = (index + 1) % self.size
      if index == original_index:
        return None
    return None

# contoh penggunaan
ht = LinearProbingHashTable(10)
ht.insert("apel", 100)
ht.insert("pisang", 200)
ht.insert("melon", 300)

print("Nilai untuk apel : ", ht.search("apel"))
print("Niali untuk melon : ", ht.search("melon"))
print("Niali untuk pisang : ", ht.search("pisang"))
print("\n")

print("--- NILAI HASH ASLI ---")
print("Hash asli 'apel'  :", hash("apel"))
print("Hash asli 'pisang':", hash("pisang"))
print("Hash asli 'melon' :", hash("melon"))

print("\n--- PROSES MODULUS 10 ---")
# 2. Melihat bagaimana angka besar tersebut berubah menjadi indeks 0-9
print(f"Index 'apel'  : {hash('apel')} % 10 = {hash('apel') % 10}")
print(f"Index 'pisang': {hash('pisang')} % 10 = {hash('pisang') % 10}")
print(f"Index 'melon' : {hash('melon')} % 10 = {hash('melon') % 10}")
print("\n")
print("--- ISI ARRAY SETELAH PROSES HASH FUNCTION ---")
for i in range(ht.size):
    print(f"indeks [{i}]: {ht.table[i]}")
# Out:
# --== Penanganan collision dengan linear probing==--
# Nilai untuk apel :  100
# Niali untuk melon :  300
# Niali untuk pisang :  200
#
#
# --- NILAI HASH ASLI ---
# Hash asli 'apel'  : -7398493956312607381
# Hash asli 'pisang': 7923829724054509074
# Hash asli 'melon' : -3575860561928314173
#
# --- PROSES MODULUS 10 ---
# Index 'apel'  : -7398493956312607381 % 10 = 9
# Index 'pisang': 7923829724054509074 % 10 = 4
# Index 'melon' : -3575860561928314173 % 10 = 7
#
#
# --- ISI ARRAY SETELAH PROSES HASH FUNCTION ---
# indeks [0]: None
# indeks [1]: None
# indeks [2]: None
# indeks [3]: None
# indeks [4]: ('pisang', 200)
# indeks [5]: None
# indeks [6]: None
# indeks [7]: ('melon', 300)
# indeks [8]: None
# indeks [9]: ('apel', 100)

# %%
print("--==Penanganan collision dengan chaining==--")

class ChainingHashTable:
  def __init__(self, size):
    self.size = size
    self.table = [[] for _ in range (size)]

  def hash_function(self, key):
    return hash(key) % self.size

  def insert(self, key, value):
    index = self.hash_function(key)
    for i, (k, v) in enumerate(self.table[index]):
      if k == key:
        self.table[index][i] = (key, value)
    self.table[index].append((key, value))

  def search(self, key):
    index = self.hash_function(key)
    for k, v in self.table[index]:
      if k == key:
          return v
    return None

#contoh penggunaan
ht = ChainingHashTable(5)
ht.insert("apel", 100)
ht.insert("pisang", 200)
ht.insert("melon", 300)

print("nilai untuk 'apel' : ", ht.search("apel"))
print("nilai untuk 'melon' : ", ht.search("melon"))
print("\n")

print("--- NILAI HASH ASLI ---")
print("Hash asli 'apel'  :", hash("apel"))
print("Hash asli 'pisang':", hash("pisang"))
print("Hash asli 'melon' :", hash("melon"))

print("\n--- PROSES MODULUS 10 (proses hash function) ---")
# 2. Melihat bagaimana angka besar tersebut berubah menjadi indeks 0-9
print(f"Index 'apel'  : {hash('apel')} % 10 = {hash('apel') % 10}")
print(f"Index 'pisang': {hash('pisang')} % 10 = {hash('pisang') % 10}")
print(f"Index 'melon' : {hash('melon')} % 10 = {hash('melon') % 10}")
print("\n")

print("--- ISI ARRAY SETELAH PROSES HASH FUNCTION ---")
for i in range(ht.size):
    print(f"Ember [{i}]: {ht.table[i]}")
# Out:
# --==Penanganan collision dengan chaining==--
# nilai untuk 'apel' :  100
# nilai untuk 'melon' :  300
#
#
# --- NILAI HASH ASLI ---
# Hash asli 'apel'  : -7398493956312607381
# Hash asli 'pisang': 7923829724054509074
# Hash asli 'melon' : -3575860561928314173
#
# --- PROSES MODULUS 10 (proses hash function) ---
# Index 'apel'  : -7398493956312607381 % 10 = 9
# Index 'pisang': 7923829724054509074 % 10 = 4
# Index 'melon' : -3575860561928314173 % 10 = 7
#
#
# --- ISI ARRAY SETELAH PROSES HASH FUNCTION ---
# Ember [0]: []
# Ember [1]: []
# Ember [2]: [('melon', 300)]
# Ember [3]: []
# Ember [4]: [('apel', 100), ('pisang', 200)]

# %%
print("__== Soal l ==__\n")

class LinearProbingHashTable:
  def __init__(self, size):
    self.size = size
    self.table = [None] * size

  def hash_function(self, key):
    return hash(key) % self.size

  def insert(self, key, value):
    index = self.hash_function(key)
    original_index = index

    while self.table[index] is not None:
      if self.table[index][0] == key:
        break
      index = (index + 1) % self.size
      if index == original_index:
        raise Exception('hash tabel penuh')

    self.table[index] = (key, value)

#a. buat objek dengan ukuran 5 tabel
ht_linear = LinearProbingHashTable(5)

#b. masukkan pasangan key-value
ht_linear.insert("A", 10)
ht_linear.insert("B", 20)
ht_linear.insert("C", 30)
ht_linear.insert("D", 40)
ht_linear.insert("E", 50)

#c. cetak isi array self.table
print("--Hasil Array--")
for i in range(ht_linear.size):
  print(f"indeks [{i}] : {ht_linear.table[i]}")
# Out:
# __== Soal l ==__
#
# --Hasil Array--
# indeks [0] : ('A', 10)
# indeks [1] : ('E', 50)
# indeks [2] : ('C', 30)
# indeks [3] : ('B', 20)
# indeks [4] : ('D', 40)

# %%
print("__== Soal 2 ==__\n")

class ChainingHashTable:
  def __init__(self, size):
    self.size = size
    self.table =[[] for _ in range(size)]

  def hash_function(self, key):
    return hash(key) % self.size

  def insert(self, key, value):
    index = self.hash_function(key)
    for i, (k, v) in enumerate(self.table[index]):
      if k == key:
        self.table[index][i] = (key, value)
        return
    self.table[index].append((key, value))

#a. gunakan ukuran tabel 3
ht_chaining = ChainingHashTable(3)

#b. masukan key-value
ht_chaining.insert('apel', 100)
ht_chaining.insert('melon', 200)
ht_chaining.insert('lemon', 300)
ht_chaining.insert('pisang', 400)

#c. cetak isi tabel (self.table) dan tampilkan semua data yang disimpan pada slot
print("--Hasil tabel chaining--")
for i in range(ht_chaining.size):
  print(f"slot [{i}] : {ht_chaining.table[i]}")
# Out:
# __== Soal 2 ==__
#
# --Hasil tabel chaining--
# slot [0] : [('melon', 200), ('lemon', 300), ('pisang', 400)]
# slot [1] : []
# slot [2] : [('apel', 100)]
